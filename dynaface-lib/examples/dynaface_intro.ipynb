# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/dynaface/blob/main/dynaface-lib/examples/dynaface_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dynaface
# You can install Dynaface with pip.

# %%
#!pip install --upgrade https://data.heatonresearch.com/library/dynaface-0.2.4-py3-none-any.whl
# !pip install dynaface==0.2.4
# Out:
# Requirement already satisfied: dynaface==0.2.4 in /usr/local/lib/python3.12/dist-packages (0.2.4)
# Requirement already satisfied: opencv-python>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from dynaface==0.2.4) (4.12.0.88)
# Requirement already satisfied: Pillow>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from dynaface==0.2.4) (11.3.0)
# Requirement already satisfied: matplotlib>=3.7.1 in /usr/local/lib/python3.12/dist-packages (from dynaface==0.2.4) (3.10.0)
# Requirement already satisfied: scikit-learn>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from dynaface==0.2.4) (1.6.1)
# Requirement already satisfied: onnxruntime>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from dynaface==0.2.4) (1.23.0)
# Requirement already satisfied: rembg>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dynaface==0.2.4) (2.0.67)
# Requirement already satisfied: facenet-pytorch in /usr/local/lib/python3.12/dist-packages (from dynaface==0.2.4) (2.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.1->dynaface==0.2.4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.1->dynaface==0.2.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.1->dynaface==0.2.4) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.1->dynaface==0.2.4) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.1->dynaface==0.2.4) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.1->dynaface==0.2.4) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.1->dynaface==0.2.4) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.1->dynaface==0.2.4) (2.9.0.post0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.20.0->dynaface==0.2.4) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.20.0->dynaface==0.2.4) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.20.0->dynaface==0.2.4) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.20.0->dynaface==0.2.4) (1.13.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from rembg>=2.0.0->dynaface==0.2.4) (4.25.1)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from rembg>=2.0.0->dynaface==0.2.4) (4.12.0.88)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from rembg>=2.0.0->dynaface==0.2.4) (1.8.2)
# Requirement already satisfied: pymatting in /usr/local/lib/python3.12/dist-packages (from rembg>=2.0.0->dynaface==0.2.4) (1.1.14)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from rembg>=2.0.0->dynaface==0.2.4) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from rembg>=2.0.0->dynaface==0.2.4) (1.16.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rembg>=2.0.0->dynaface==0.2.4) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.2->dynaface==0.2.4) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.2->dynaface==0.2.4) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from facenet-pytorch->dynaface==0.2.4) (2.32.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from facenet-pytorch->dynaface==0.2.4) (0.23.0+cu126)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.1->dynaface==0.2.4) (1.17.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime>=1.20.0->dynaface==0.2.4) (10.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg>=2.0.0->dynaface==0.2.4) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg>=2.0.0->dynaface==0.2.4) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg>=2.0.0->dynaface==0.2.4) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg>=2.0.0->dynaface==0.2.4) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->rembg>=2.0.0->dynaface==0.2.4) (4.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->facenet-pytorch->dynaface==0.2.4) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->facenet-pytorch->dynaface==0.2.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->facenet-pytorch->dynaface==0.2.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->facenet-pytorch->dynaface==0.2.4) (2025.8.3)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting->rembg>=2.0.0->dynaface==0.2.4) (0.60.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg>=2.0.0->dynaface==0.2.4) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg>=2.0.0->dynaface==0.2.4) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg>=2.0.0->dynaface==0.2.4) (2025.9.9)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg>=2.0.0->dynaface==0.2.4) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.20.0->dynaface==0.2.4) (1.3.0)
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->facenet-pytorch->dynaface==0.2.4) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (75.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (3.4.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting->rembg>=2.0.0->dynaface==0.2.4) (0.43.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0->torchvision->facenet-pytorch->dynaface==0.2.4) (3.0.2)

# %%
import dynaface
print(f"Dynaface-lib version: {dynaface.__version__}")
# Out:
# Dynaface-lib version: 0.2.4

# %% [markdown]
# The following method is used to display OpenCV images.

# %%
# %matplotlib inline

def display_image(img):
  plt.imshow(img)
  plt.axis('off')  # Hide axes
  plt.show()

# %% [markdown]
# You may have to restart your Colab environment due to the install.
#
# Dynaface uses Python logging, if you would like to see it, set the log level to what is desired.

# %%
import logging
import sys

log_level = logging.INFO

# Remove any existing handlers
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

# Set up a new handler that logs to the console at DEBUG level
console_handler = logging.StreamHandler(sys.stdout)
console_handler.setLevel(log_level)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
console_handler.setFormatter(formatter)

# Add the handler to the root logger
logging.root.setLevel(log_level)
logging.root.addHandler(console_handler)

# %% [markdown]
# Dynaface makes use of several models, which must be downloaded or embedded into your application. The following code downloads the models.

# %%
from dynaface import facial, measures, models
import dynaface

print("...Downloading models... please wait...")
# Choose device
device = models.detect_device()
print(f"Detected device: {device}")

# Download and init models
dynaface.util.VERIFY_CERTS = True # Prvent warnings, remove if downloads fail
path = models.download_models()
models.init_models(path, device)
# Out:
# ...Downloading models... please wait...
# Detected device: cpu
# 2025-09-29 15:23:28,851 - INFO - SPIGA model loaded

# %% [markdown]
# Load an image and convert to CV2.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO

# Provide the image URL
image_url = "https://www.heatonresearch.com/images/jeff/about-jeff-heaton-2020.jpg"  # Replace with the actual image URL

# Download the image
response = requests.get(image_url)
image_array = np.array(bytearray(response.content), dtype=np.uint8)

# Decode the image using OpenCV
image = cv2.imdecode(image_array, cv2.IMREAD_COLOR)

# Convert BGR to RGB (OpenCV loads images in BGR format)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# display the image
display_image(image_rgb)

# %% [markdown]
# Analyze the image and print out key measures.

# %%
import cv2

all_measures = measures.all_measures()
face = facial.AnalyzeFace(measures = all_measures)
face.load_image(image_rgb,crop=True)
face.analyze()
# Out:
# 2025-09-29 15:23:37,181 - INFO - Headpose: yaw:5.309793949127197, pitch:10.478902816772461, roll:-1.2487545013427734
# {'fai': 1.7292713673131246,
#  'oce.l': 26.010917099862606,
#  'oce.r': 30.431062066332984,
#  'brow.d': 0.49215370764687766,
#  'dental_area': 293.86767869402684,
#  'dental_left': 138.57741246472142,
#  'dental_right': 155.29026622930542,
#  'dental_ratio': 0.8923766816143816,
#  'dental_diff': 16.712853764583997,
#  'eye.left': 75.4197803036077,
#  'eye.right': 88.04525135402946,
#  'eye.diff': 12.63,
#  'eye.ratio': 0.856602475928488,
#  'id': 29.041239245801457,
#  'ml': 48.738749736089986,
#  'nostril': 33.480924099959225,
#  'nose.tip': 14.026380667936014,
#  'dorsal.base': 28.052761335872027,
#  'dorsal.bridge': 14.026380667936014,
#  'oe': 68.65588321326902,
#  'tilt': 0.575817593244949,
#  'px2mm': 0.31656692715165563,
#  'pd': 199.01004999748127,
#  'pitch': np.float64(10.478902816772461),
#  'roll': np.float64(-1.2487545013427734),
#  'yaw': np.float64(5.309793949127197),
#  'hsv': None}

# %% [markdown]
# Display the images with measures marked.

# %%
# Display the image
plt.imshow(face.render_img)
plt.axis('off')  # Hide axes
plt.show()
